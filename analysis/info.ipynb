# %%
from utils import get_market_df, cot_year, get_report_type_cols, get_report_type_cols, get_markets, LEGUACY_FUT, LEGACY_FUTOPT, DISAGGREGATED_FUT, TRADERS_IN_FINANCIAL_FUTURES_FUT

import json

# %% [markdown]
# - **Cols**

# %%
# for report_type in [
#     LEGUACY_FUT,
#     DISAGGREGATED_FUT,
#     TRADERS_IN_FINANCIAL_FUTURES_FUT,
# ]:
#     get_report_type_cols(cot_report_type=report_type, save=False)
#     print('----------------------------------------------------------')

# %% [markdown]
# - **Markets**

# %%
# df = get_markets(cot_report_type=DISAGGREGATED_FUT, save_json=True)

# df
