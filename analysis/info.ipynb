# %%
from utils import cot_year, get_report_type_cols, get_report_type_cols, get_markets, LEGUACY_FUT, LEGACY_FUTOPT, DISAGGREGATED_FUT, TRADERS_IN_FINANCIAL_FUTURES_FUT

import json

# %% [markdown]
# - **Cols**

# %%
# for market in [
#     LEGUACY_FUT,
#     DISAGGREGATED_FUT,
#     TRADERS_IN_FINANCIAL_FUTURES_FUT,
# ]:
#     get_report_type_cols(cot_report_type=market, save=False)
#     print('----------------------------------------------------------')

# %% [markdown]
# - **Markets**

# %%
df = get_markets(cot_report_type=DISAGGREGATED_FUT, save_json=True)

df
# Out:
# Selected: Disaggregated Report Futures-only from year: 2026 - loading data ...
#      market_code                     market_name
# 6         001602                       WHEAT-SRW
# 13        001612                       WHEAT-HRW
# 20        001626                  WHEAT-HRSpring
# 27        002602                            CORN
# 31        004603                            OATS
# ...          ...                             ...
# 1858      192691  NORTH EURO HOT-ROLL COIL STEEL
# 1865      406651         PGP PROPYLENE (PCW) CAL
# 1872      86465A        GULF JET NY HEAT OIL SPR
# 1876      86465K               JET UP-DOWN BALMO
# 1883      86565A         GULF # 6 FUEL OIL CRACK
#
# [289 rows x 2 columns]
