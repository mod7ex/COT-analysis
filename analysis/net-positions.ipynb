# %%
from utils import get_market_df, plot_df_line_chart, TRADERS_IN_FINANCIAL_FUTURES_FUT, LEGUACY_FUT, DISAGGREGATED_FUT
from analysis import get_market_net

# %%
df = get_market_df(cot_report_type=DISAGGREGATED_FUT, market="GOLD")
# Out:
# loading data for the report type: disaggregated_fut ...
# Selected: Disaggregated Report Futures-only - loading historical data ...
# Selected: Disaggregated Report Futures-only from year: 2017 - loading data ...
# Selected: Disaggregated Report Futures-only from year: 2018 - loading data ...
# Selected: Disaggregated Report Futures-only from year: 2019 - loading data ...
# Selected: Disaggregated Report Futures-only from year: 2020 - loading data ...
# Selected: Disaggregated Report Futures-only from year: 2021 - loading data ...
# Selected: Disaggregated Report Futures-only from year: 2022 - loading data ...
# Selected: Disaggregated Report Futures-only from year: 2023 - loading data ...
# Selected: Disaggregated Report Futures-only from year: 2024 - loading data ...
# Selected: Disaggregated Report Futures-only from year: 2025 - loading data ...
# Selected: Disaggregated Report Futures-only from year: 2026 - loading data ...

# %%
df.tail(4)
# Out:
#                  market_and_exchange_names  as_of_date_in_form_yymmdd  \
# Date
# 2026-01-20  GOLD - COMMODITY EXCHANGE INC.                     260120
# 2026-01-27  GOLD - COMMODITY EXCHANGE INC.                     260127
# 2026-02-03  GOLD - COMMODITY EXCHANGE INC.                     260203
# 2026-02-10  GOLD - COMMODITY EXCHANGE INC.                     260210
#
#            cftc_contract_market_code cftc_market_code  cftc_region_code  \
# Date
# 2026-01-20                    088691             CMX                  1
# 2026-01-27                    088691             CMX                  1
# 2026-02-03                    088691             CMX                  1
# 2026-02-10                    088691             CMX                  1
#
#             cftc_commodity_code  open_interest_all  \
# Date
# 2026-01-20                   88             528004
# 2026-01-27                   88             488463
# 2026-02-03                   88             409694
# 2026-02-10                   88             404391
#
#             prod_merc_positions_long_all  prod_merc_positions_short_all  \
# Date
# 2026-01-20                         18731                          61020
# 2026-01-27                         14609                          55198
# 2026-02-03                         14072                          38706
# 2026-02-10                         15737                          34182
#
#             swap_positions_long_all  ...  conc_net_le_4_tdr_long_other  \
# Date                                 ...
# 2026-01-20                    29522  ...                           0.0
# 2026-01-27                    34124  ...                           0.0
# 2026-02-03                    40303  ...                           0.0
# 2026-02-10                    43244  ...                           0.0
#
#             conc_net_le_4_tdr_short_other  conc_net_le_8_tdr_long_other  \
# Date
# 2026-01-20                            0.0                           0.0
# 2026-01-27                            0.0                           0.0
# 2026-02-03                            0.0                           0.0
# 2026-02-10                            0.0                           0.0
#
#             conc_net_le_8_tdr_short_other                  contract_units  \
# Date
# 2026-01-20                            0.0  (CONTRACTS OF 100 TROY OUNCES)
# 2026-01-27                            0.0  (CONTRACTS OF 100 TROY OUNCES)
# 2026-02-03                            0.0  (CONTRACTS OF 100 TROY OUNCES)
# 2026-02-10                            0.0  (CONTRACTS OF 100 TROY OUNCES)
#
#             cftc_contract_market_code_quotes  cftc_market_code_quotes  \
# Date
# 2026-01-20                            088691                     CMX
# 2026-01-27                            088691                     CMX
# 2026-02-03                            088691                     CMX
# 2026-02-10                            088691                     CMX
#
#             cftc_commodity_code_quotes  cftc_subgroup_code  \
# Date
# 2026-01-20                          88                 N20
# 2026-01-27                          88                 N20
# 2026-02-03                          88                 N20
# 2026-02-10                          88                 N20
#
#             futonly_or_combined
# Date
# 2026-01-20              FutOnly
# 2026-01-27              FutOnly
# 2026-02-03              FutOnly
# 2026-02-10              FutOnly
#
# [4 rows x 190 columns]

# %% [markdown]
# - **compute net positions**

# %%
df_net = get_market_net(df)

df_net.tail()
# Out:
#             Net_prod_merc  Net_swap  Net_m_money  Net_other_rept  \
# Date
# 2026-01-13         -51165   -245941       134745          116493
# 2026-01-20         -42289   -247400       137444          107326
# 2026-01-27         -40589   -207696       118159           87237
# 2026-02-03         -24634   -183144        92072           73532
# 2026-02-10         -18445   -179293        92022           67990
#
#             Net_tot_rept  Net_nonrept
# Date
# 2026-01-13        -45868        45868
# 2026-01-20        -44919        44919
# 2026-01-27        -42889        42889
# 2026-02-03        -42174        42174
# 2026-02-10        -37726        37726

# %% [markdown]
# # **Plots**

# %%
plot_df_line_chart(
    df = df_net,
    chart_title = "Net Positions of different market participants"
)
