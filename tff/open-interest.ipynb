# %%
from utils import get_df, plot_df_line_chart
from _tff import get_df_oi

# %%
df = get_df()
# Out:
# loading data for the report type: traders_in_financial_futures_fut ...
# Selected: Traders in Financial Futures (TFF) - loading historical data ...
# Selected: Traders in Financial Futures (TFF) from year: 2017 - loading data ...
# Selected: Traders in Financial Futures (TFF) from year: 2018 - loading data ...
# Selected: Traders in Financial Futures (TFF) from year: 2019 - loading data ...
# Selected: Traders in Financial Futures (TFF) from year: 2020 - loading data ...
# Selected: Traders in Financial Futures (TFF) from year: 2021 - loading data ...
# Selected: Traders in Financial Futures (TFF) from year: 2022 - loading data ...
# Selected: Traders in Financial Futures (TFF) from year: 2023 - loading data ...
# Selected: Traders in Financial Futures (TFF) from year: 2024 - loading data ...
# Selected: Traders in Financial Futures (TFF) from year: 2025 - loading data ...
# Selected: Traders in Financial Futures (TFF) from year: 2026 - loading data ...

# %%
df.tail(4)
# Out:
#                         Market_and_Exchange_Names  As_of_Date_In_Form_YYMMDD  \
# Date
# 2026-01-13  EURO FX - CHICAGO MERCANTILE EXCHANGE                     260113
# 2026-01-20  EURO FX - CHICAGO MERCANTILE EXCHANGE                     260120
# 2026-01-27  EURO FX - CHICAGO MERCANTILE EXCHANGE                     260127
# 2026-02-03  EURO FX - CHICAGO MERCANTILE EXCHANGE                     260203
#
#            CFTC_Contract_Market_Code CFTC_Market_Code  CFTC_Region_Code  \
# Date
# 2026-01-13                    099741             CME                  0
# 2026-01-20                    099741             CME                  0
# 2026-01-27                    099741             CME                  0
# 2026-02-03                    099741             CME                  0
#
#             CFTC_Commodity_Code  Open_Interest_All  Dealer_Positions_Long_All  \
# Date
# 2026-01-13                   99           883672.0                    52405.0
# ...

# %% [markdown]
# - **compute Open interest**

# %%
df_oi = get_df_oi(df)

df_oi.tail()
# Out:
#                   OI  OI_Long_Dealer  OI_Short_Dealer  OI_Spread_Dealer  \
# Date
# 2026-01-06  881815.0       44972.565       556425.265          3527.260
# 2026-01-13  883672.0       52136.648       537272.576          4418.360
# 2026-01-20  880948.0       60785.412       512711.736          3523.792
# 2026-01-27  919284.0       57914.892       547893.264          5515.704
# 2026-02-03  910464.0       56448.768       569950.464          6373.248
#
#             OI_Long_Asset_Mgr  OI_Short_Asset_Mgr  OI_Spread_Asset_Mgr  \
# Date
# 2026-01-06         544079.855          144617.660            32627.155
# 2026-01-13         554946.016          151107.912            34463.208
# 2026-01-20         543544.916          152404.004            33476.024
# 2026-01-27         550651.116          147085.440            34013.508
# 2026-02-03         538994.688          134748.672            34597.632
#
#             OI_Long_Lev_Money  OI_Short_Lev_Money  OI_Spread_Lev_Money  \
# Date
# ...

# %% [markdown]
# # **Plots**

# %%
plot_df_line_chart(
    df = df_oi,
    chart_title = "Open Interest distribution among different market participants (Traders in Financial Futures)"
)
