# %%
from utils import get_report_type_cols, get_markets, TRADERS_IN_FINANCIAL_FUTURES_FUT

get_report_type_cols(cot_report_type=TRADERS_IN_FINANCIAL_FUTURES_FUT)
# Out:
# Selected: Traders in Financial Futures (TFF) from year: 2026 - loading data ...
# | 1 | Market_and_Exchange_Names |
# | 2 | As_of_Date_In_Form_YYMMDD |
# | 3 | Report_Date_as_YYYY-MM-DD |
# | 4 | CFTC_Contract_Market_Code |
# | 5 | CFTC_Market_Code |
# | 6 | CFTC_Region_Code |
# | 7 | CFTC_Commodity_Code |
# | 8 | Open_Interest_All |
# | 9 | Dealer_Positions_Long_All |
# | 10 | Dealer_Positions_Short_All |
# | 11 | Dealer_Positions_Spread_All |
# | 12 | Asset_Mgr_Positions_Long_All |
# | 13 | Asset_Mgr_Positions_Short_All |
# | 14 | Asset_Mgr_Positions_Spread_All |
# | 15 | Lev_Money_Positions_Long_All |
# | 16 | Lev_Money_Positions_Short_All |
# | 17 | Lev_Money_Positions_Spread_All |
# | 18 | Other_Rept_Positions_Long_All |
# | 19 | Other_Rept_Positions_Short_All |
# | 20 | Other_Rept_Positions_Spread_All |
# | 21 | Tot_Rept_Positions_Long_All |
# | 22 | Tot_Rept_Positions_Short_All |
# | 23 | NonRept_Positions_Long_All |
# | 24 | NonRept_Positions_Short_All |
# ...

# %% [markdown]
# - **Cols**

# %% [markdown]
# - **Markets**

# %%
df = get_markets(cot_report_type=TRADERS_IN_FINANCIAL_FUTURES_FUT, save_json=True)

df
# Out:
# Selected: Traders in Financial Futures (TFF) from year: 2026 - loading data ...
#     Market_Code                                    Market_Name
# 0        090741  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 1        090741  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 2        090741  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 3        090741  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 4        090741  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# ..          ...                                            ...
# 406      221602         BBG COMMODITY - CHICAGO BOARD OF TRADE
# 407      221602         BBG COMMODITY - CHICAGO BOARD OF TRADE
# 408      221602         BBG COMMODITY - CHICAGO BOARD OF TRADE
# 409      221602         BBG COMMODITY - CHICAGO BOARD OF TRADE
# 410      221602         BBG COMMODITY - CHICAGO BOARD OF TRADE
#
# [411 rows x 2 columns]
