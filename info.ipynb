# %%
from utils import cot_year, get_report_type_cols, LEGUACY_FUT, LEGACY_FUTOPT, SUPPLEMENTAL_FUTOPT, DISAGGREGATED_FUT, DISAGGREGATED_FUTOPT, TRADERS_IN_FINANCIAL_FUTURES_FUT, TRADERS_IN_FINANCIAL_FUTURES_FUTOPT, get_report_type_cols, get_markets

from config import csv_markets_path, json_markets_path

import json

# %% [markdown]
# - **Cols**

# %%
# for market in [
#     LEGUACY_FUT,
#     DISAGGREGATED_FUT,
#     TRADERS_IN_FINANCIAL_FUTURES_FUT,
# ]:
#     get_report_type_cols(cot_report_type=market, save=True)

# %% [markdown]
# - **Markets**

# %%
# df = get_markets(cot_report_type=DISAGGREGATED_FUT, save_json=True)
#
# df
